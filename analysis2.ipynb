# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\jbt\\python\\data\\countries.csv')

# %%
df
# Out:
#       year   country  population  world_population
# 0     2020     China  1439323776        7794798739
# 1     2019     China  1433783686        7713468100
# 2     2018     China  1427647786        7631091040
# 3     2017     China  1421021791        7547858925
# 4     2016     China  1414049351        7464022049
# ...    ...       ...         ...               ...
# 4190  1975  Holy See         728        4079480606
# 4191  1970  Holy See         644        3700437046
# 4192  1965  Holy See         854        3339583597
# 4193  1960  Holy See         906        3034949748
# 4194  1955  Holy See         908        2773019936
#
# [4195 rows x 4 columns]

# %%
df.head(10)
# Out:
#    year country  population  world_population
# 0  2020   China  1439323776        7794798739
# 1  2019   China  1433783686        7713468100
# 2  2018   China  1427647786        7631091040
# 3  2017   China  1421021791        7547858925
# 4  2016   China  1414049351        7464022049
# 5  2015   China  1406847870        7379797139
# 6  2010   China  1368810615        6956823603
# 7  2005   China  1330776380        6541907027
# 8  2000   China  1290550765        6143493823
# 9  1995   China  1240920535        5744212979

# %%
df.tail(10)
# Out:
#       year   country  population  world_population
# 4185  2000  Holy See         785        6143493823
# 4186  1995  Holy See         780        5744212979
# 4187  1990  Holy See         768        5327231061
# 4188  1985  Holy See         746        4870921740
# 4189  1980  Holy See         724        4458003514
# 4190  1975  Holy See         728        4079480606
# 4191  1970  Holy See         644        3700437046
# 4192  1965  Holy See         854        3339583597
# 4193  1960  Holy See         906        3034949748
# 4194  1955  Holy See         908        2773019936

# %%
df.iloc[0]
# Out:
# year                      2020
# country                  China
# population          1439323776
# world_population    7794798739
# Name: 0, dtype: object

# %%
df.loc[0,'year']
# Out:
# np.int64(2020)

# %%
df[df['year']==2020]
# Out:
#       year              country  population  world_population
# 0     2020                China  1439323776        7794798739
# 18    2020                India  1380004385        7794798739
# 36    2020        United States   331002651        7794798739
# 54    2020            Indonesia   273523615        7794798739
# 72    2020             Pakistan   220892340        7794798739
# ...    ...                  ...         ...               ...
# 3527  2020                Aruba      106766        7794798739
# 3545  2020                Tonga      105695        7794798739
# 3563  2020  U.S. Virgin Islands      104425        7794798739
# 3581  2020           Seychelles       98347        7794798739
# 3599  2020  Antigua and Barbuda       97929        7794798739
#
# [200 rows x 4 columns]

# %%
x=df[df['year']==1980]

# %%
x
# Out:
#       year           country  population  world_population
# 12    1980             China  1000089235        4458003514
# 30    1980             India   698952844        4458003514
# 48    1980     United States   229476354        4458003514
# 66    1980         Indonesia   147447836        4458003514
# 84    1980          Pakistan    78054343        4458003514
# ...    ...               ...         ...               ...
# 4121  1980        Montserrat       11607        4458003514
# 4138  1980  Falkland Islands        1854        4458003514
# 4155  1980              Niue        3404        4458003514
# 4172  1980           Tokelau        1553        4458003514
# 4189  1980          Holy See         724        4458003514
#
# [235 rows x 4 columns]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x[['country']]
# Out:
#                country
# 12               China
# 30               India
# 48       United States
# 66           Indonesia
# 84            Pakistan
# ...                ...
# 4121        Montserrat
# 4138  Falkland Islands
# 4155              Niue
# 4172           Tokelau
# 4189          Holy See
#
# [235 rows x 1 columns]

# %%
x[['country','year']]
# Out:
#                country  year
# 12               China  1980
# 30               India  1980
# 48       United States  1980
# 66           Indonesia  1980
# 84            Pakistan  1980
# ...                ...   ...
# 4121        Montserrat  1980
# 4138  Falkland Islands  1980
# 4155              Niue  1980
# 4172           Tokelau  1980
# 4189          Holy See  1980
#
# [235 rows x 2 columns]

# %%
x=x.rename({'country':'cccc'},axis='columns')
# Out:
#       year              cccc  population  world_population
# 12    1980             China  1000089235        4458003514
# 30    1980             India   698952844        4458003514
# 48    1980     United States   229476354        4458003514
# 66    1980         Indonesia   147447836        4458003514
# 84    1980          Pakistan    78054343        4458003514
# ...    ...               ...         ...               ...
# 4121  1980        Montserrat       11607        4458003514
# 4138  1980  Falkland Islands        1854        4458003514
# 4155  1980              Niue        3404        4458003514
# 4172  1980           Tokelau        1553        4458003514
# 4189  1980          Holy See         724        4458003514
#
# [235 rows x 4 columns]

# %%
x
# Out:
#       year           country  population  world_population
# 12    1980             China  1000089235        4458003514
# 30    1980             India   698952844        4458003514
# 48    1980     United States   229476354        4458003514
# 66    1980         Indonesia   147447836        4458003514
# 84    1980          Pakistan    78054343        4458003514
# ...    ...               ...         ...               ...
# 4121  1980        Montserrat       11607        4458003514
# 4138  1980  Falkland Islands        1854        4458003514
# 4155  1980              Niue        3404        4458003514
# 4172  1980           Tokelau        1553        4458003514
# 4189  1980          Holy See         724        4458003514
#
# [235 rows x 4 columns]

# %%
x.groupby('country').mean()
# Out:
#                    year  population  world_population
# country
# Afghanistan      1980.0  13356511.0      4.458004e+09
# Albania          1980.0   2682690.0      4.458004e+09
# Algeria          1980.0  19221665.0      4.458004e+09
# American Samoa   1980.0     32646.0      4.458004e+09
# Andorra          1980.0     36067.0      4.458004e+09
# ...                 ...         ...               ...
# Wallis & Futuna  1980.0     11231.0      4.458004e+09
# Western Sahara   1980.0    150877.0      4.458004e+09
# Yemen            1980.0   7941898.0      4.458004e+09
# Zambia           1980.0   5851825.0      4.458004e+09
# Zimbabwe         1980.0   7408624.0      4.458004e+09
#
# [235 rows x 3 columns]

# %%
y=x.groupby('country')['population'].mean()#avg

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y
# Out:
# country
# Afghanistan        13356511.0
# Albania             2682690.0
# Algeria            19221665.0
# American Samoa        32646.0
# Andorra               36067.0
#                       ...
# Wallis & Futuna       11231.0
# Western Sahara       150877.0
# Yemen               7941898.0
# Zambia              5851825.0
# Zimbabwe            7408624.0
# Name: population, Length: 235, dtype: float64

# %%
y=x.groupby('country')['population'].sum()

# %%
y
# Out:
# country
# Afghanistan        13356511
# Albania             2682690
# Algeria            19221665
# American Samoa        32646
# Andorra               36067
#                      ...
# Wallis & Futuna       11231
# Western Sahara       150877
# Yemen               7941898
# Zambia              5851825
# Zimbabwe            7408624
# Name: population, Length: 235, dtype: int64

# %%
x.groupby('country')['population'].max()
# Out:
# country
# Afghanistan        13356511
# Albania             2682690
# Algeria            19221665
# American Samoa        32646
# Andorra               36067
#                      ...
# Wallis & Futuna       11231
# Western Sahara       150877
# Yemen               7941898
# Zambia              5851825
# Zimbabwe            7408624
# Name: population, Length: 235, dtype: int64

# %%
x.groupby('country')['population'].min()
# Out:
# country
# Afghanistan        13356511
# Albania             2682690
# Algeria            19221665
# American Samoa        32646
# Andorra               36067
#                      ...
# Wallis & Futuna       11231
# Western Sahara       150877
# Yemen               7941898
# Zambia              5851825
# Zimbabwe            7408624
# Name: population, Length: 235, dtype: int64

# %%
x.groupby('country')['population'].count()
# Out:
# country
# Afghanistan        1
# Albania            1
# Algeria            1
# American Samoa     1
# Andorra            1
#                   ..
# Wallis & Futuna    1
# Western Sahara     1
# Yemen              1
# Zambia             1
# Zimbabwe           1
# Name: population, Length: 235, dtype: int64

# %%
x.groupby('country')['population'].countunique()#############################################
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 x.groupby('country')['population'].countunique()
#
# File C:\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'countunique'

# %%
df.groupby('country')[['population','world_population']].min()
# Out:
#                  population  world_population
# country
# Afghanistan         8270991        2773019936
# Albania             1419994        2773019936
# Algeria             9774283        2773019936
# American Samoa        19754        2773019936
# Andorra                9232        2773019936
# ...                     ...               ...
# Wallis & Futuna        7669        2773019936
# Western Sahara        21147        2773019936
# Yemen               4965574        2773019936
# Zambia              2644976        2773019936
# Zimbabwe            3213286        2773019936
#
# [235 rows x 2 columns]

# %%
#pip3 install seaborn

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
png=sns.load_dataset('penguins')

# %%
png
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#bodymass under 3000 species='Adelie'
png[(png['body_mass_g']<3000) & (png['species']=='Adelie')]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 47   Adelie      Dream            37.5           18.9              179.0
# 54   Adelie     Biscoe            34.5           18.1              187.0
# 58   Adelie     Biscoe            36.5           16.6              181.0
# 64   Adelie     Biscoe            36.4           17.1              184.0
# 98   Adelie      Dream            33.1           16.1              178.0
# 104  Adelie     Biscoe            37.9           18.6              193.0
# 116  Adelie  Torgersen            38.6           17.0              188.0
#
#      body_mass_g     sex
# 47        2975.0     NaN
# 54        2900.0  Female
# 58        2850.0  Female
# 64        2850.0  Female
# 98        2900.0  Female
# 104       2925.0  Female
# 116       2900.0  Female

# %%
png.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# ...

# %%
t=png.isnull()

# %%
t.values.sum()
# Out:
# np.int64(19)

# %%
png.isnull().values.any()
# Out:
# np.True_

# %%
png['bill_length_mm'].isnull().values.sum()
# Out:
# np.int64(2)

# %%
print(344*7-19)
# Out:
# 2389

# %%
19/2400
# Out:
# 0.007916666666666667

# %%
png.groupby('species')['body_mass_g'].mean()
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %%
sns.set_style('whitegrid')
sns.barplot(data=png,x='species',y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(data=png,x='species',y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.set_style('darkgrid')
sns.barplot(data=png,x='species',y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(y='species',x='body_mass_g',data=png)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='species'>

# %%
color={'Adelie':'#89D8FF',
 'Chinstrap':'#9FCEFD',
 'Gentoo':'blue'
}

# %%
sns.barplot(data=png,x='species',y='body_mass_g',palette=color)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_1272\2931150846.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=png,x='species',y='body_mass_g',palette=color)
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(data=png,x='species',y='body_mass_g',hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
color1={'Male':'#89D8FF',
 'Female':'red'
}

# %%
sns.barplot(data=png,x='species',y='body_mass_g',hue='sex',palette=color1)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#for each island -->show the flipper length avg in bar plot--> hue by species
colors={
'Adelie':'#FD9FE7',
'Chinstrap':'#F730C9',
'Gentoo':'#89056A'}

# %%
sns.barplot(data=png,x='island',y='flipper_length_mm',hue='species',palette=colors)
# Out:
# <Axes: xlabel='island', ylabel='flipper_length_mm'>

# %%
import matplotlib.pyplot as plt

# %%
plt.show()#for showing the graph in pyCharm/VisualStudio etc.

# %%
sns.barplot(data=png,x='species',y='body_mass_g',hue='sex',palette=color1)
plt.legend(loc='upper center')
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.title("pgs avg mass by species",color='green',size=24)
plt.xlabel('type',color='green',size=14)
plt.ylabel('mass(g)',color='green',size=14)
sns.barplot(data=png,x='species',y='body_mass_g',hue='sex',palette=color1)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.barplot(data=png,x='island',y='flipper_length_mm',hue='species',palette=colors)
# Out:
# <Axes: xlabel='island', ylabel='flipper_length_mm'>

# %%
plt.title("pgs avg mass by species",color='green',size=24)
plt.xlabel('type',color='green',size=14)
plt.figure(figsize=(12,10))
sns.barplot(data=png,x='species',y='body_mass_g',hue='sex',palette=color1)
plt.show()
plt.ylabel('mass(g)',color='green',size=14)
# Out:
# Text(0, 0.5, 'mass(g)')

# %%
tit=sns.load_dataset('titanic')

# %%
tit
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#create a bigger frame 
#create bar plot for each pclass show how many survived
#add title and labels
plt.figure(figsize=(16,10))
sns.barplot(data=tit,x='pclass',y='survived',estimator='sum')
plt.show()

# %%
#pip install pandasql
import pandasql as pds

# %%
t=pds.sqldf("""select * from tit;""",globals())

# %%
type(t)
# Out:
# pandas.core.frame.DataFrame

# %%
pds.sqldf("""select * from tit limit 10;""",globals())#select top 10 *....
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male  deck  embark_town alive  alone
# 0    man           1  None  Southampton    no      0
# ...

# %%
pds.sqldf("""select * from tit order by age ;""",globals())#select top 10 *....
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male   NaN      0      0   8.4583        Q   Third
# 1           1       2    male   NaN      0      0  13.0000        S  Second
# 2           1       3  female   NaN      0      0   7.2250        C   Third
# 3           0       3    male   NaN      0      0   7.2250        C   Third
# 4           1       3  female   NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       3    male  70.5      0      0   7.7500        Q   Third
# 887         0       1    male  71.0      0      0  34.6542        C   First
# 888         0       1    male  71.0      0      0  49.5042        C   First
# 889         0       3    male  74.0      0      0   7.7750        S   Third
# 890         1       1    male  80.0      0      0  30.0000        S   First
#
#        who  adult_male  deck  embark_town alive  alone
# ...

# %%
pds.sqldf("""select * from tit order by age desc ;""",globals())#select top 10 *....
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           1       1    male  80.0      0      0  30.0000        S  First
# 1           0       3    male  74.0      0      0   7.7750        S  Third
# 2           0       1    male  71.0      0      0  34.6542        C  First
# 3           0       1    male  71.0      0      0  49.5042        C  First
# 4           0       3    male  70.5      0      0   7.7500        Q  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       3    male   NaN      0      0   7.2292        C  Third
# 887         0       3  female   NaN      8      2  69.5500        S  Third
# 888         0       3    male   NaN      0      0   9.5000        S  Third
# 889         0       3    male   NaN      0      0   7.8958        S  Third
# 890         0       3  female   NaN      1      2  23.4500        S  Third
#
#        who  adult_male  deck  embark_town alive  alone
# ...

# %%
pds.sqldf("""select * from tit order by age desc limit 7  ;""",globals())#select top 10 *....
# Out:
#    survived  pclass   sex   age  sibsp  parch     fare embarked   class  who  \
# 0         1       1  male  80.0      0      0  30.0000        S   First  man
# 1         0       3  male  74.0      0      0   7.7750        S   Third  man
# 2         0       1  male  71.0      0      0  34.6542        C   First  man
# 3         0       1  male  71.0      0      0  49.5042        C   First  man
# 4         0       3  male  70.5      0      0   7.7500        Q   Third  man
# 5         0       2  male  70.0      0      0  10.5000        S  Second  man
# 6         0       1  male  70.0      1      1  71.0000        S   First  man
#
#    adult_male  deck  embark_town alive  alone
# 0           1     A  Southampton   yes      1
# 1           1  None  Southampton    no      1
# 2           1     A    Cherbourg    no      1
# 3           1  None    Cherbourg    no      1
# 4           1  None   Queenstown    no      1
# 5           1  None  Southampton    no      1
# ...

# %%
tit.sort_values(by='age',ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 630         1       1    male  80.0      0      0  30.0000        S  First
# 851         0       3    male  74.0      0      0   7.7750        S  Third
# 493         0       1    male  71.0      0      0  49.5042        C  First
# 96          0       1    male  71.0      0      0  34.6542        C  First
# 116         0       3    male  70.5      0      0   7.7500        Q  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 859         0       3    male   NaN      0      0   7.2292        C  Third
# 863         0       3  female   NaN      8      2  69.5500        S  Third
# 868         0       3    male   NaN      0      0   9.5000        S  Third
# 878         0       3    male   NaN      0      0   7.8958        S  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tit.sort_values(by='age',ascending=False).head(7)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 630         1       1  male  80.0      0      0  30.0000        S   First
# 851         0       3  male  74.0      0      0   7.7750        S   Third
# 493         0       1  male  71.0      0      0  49.5042        C   First
# 96          0       1  male  71.0      0      0  34.6542        C   First
# 116         0       3  male  70.5      0      0   7.7500        Q   Third
# 745         0       1  male  70.0      1      1  71.0000        S   First
# 672         0       2  male  70.0      0      0  10.5000        S  Second
#
#      who  adult_male deck  embark_town alive  alone
# 630  man        True    A  Southampton   yes   True
# 851  man        True  NaN  Southampton    no   True
# 493  man        True  NaN    Cherbourg    no   True
# 96   man        True    A    Cherbourg    no   True
# 116  man        True  NaN   Queenstown    no   True
# 745  man        True    B  Southampton    no  False
# ...

# %%
#show all the passengers who were in first class (use pandasql for first option,use filter on df )
pds.sqldf("""select * from tit where class='First' ;""",globals())
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           1       1  female  38.0      1      0  71.2833        C  First
# 1           1       1  female  35.0      1      0  53.1000        S  First
# 2           0       1    male  54.0      0      0  51.8625        S  First
# 3           1       1  female  58.0      0      0  26.5500        S  First
# 4           1       1    male  28.0      0      0  35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 211         1       1  female  47.0      1      1  52.5542        S  First
# 212         0       1    male  33.0      0      0   5.0000        S  First
# 213         1       1  female  56.0      0      1  83.1583        C  First
# 214         1       1  female  19.0      0      0  30.0000        S  First
# 215         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tit[tit['class']=='First']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 23          1       1    male  28.0      0      0  35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
plt.figure(figsize=(16,10))
x=sns.barplot(data=tit,x='pclass',y='survived',estimator='sum')
for con in x.containers:
    x.bar_label(con,fmt="%.1f")
plt.show()

# %%
type(x)
# Out:
# matplotlib.axes._axes.Axes
